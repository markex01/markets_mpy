# %%
# from bloomberg.api_helper.trial import trial

from bloomberg.api_helper import trial

# import numpy

# %%
from bloomberg.api_helper.extractor_ref import BloombergExtractor 

be = BloombergExtractor()

df = be.search_securities(query='FR')

df
# Eurostat Germany HICP All Items YoY NSA
# Out:
# Sesión Bloomberg iniciada
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 from bloomberg.api_helper.extractor_ref import BloombergExtractor
# ----> 3 be = BloombergExtractor()
#       5 df = be.search_securities(query='FR')
#       7 df
#
# File ~\Python Unified\packages\bloomberg\src\bloomberg\api_helper\extractor_ref.py:22, in BloombergExtractor.__init__(self, host, port)
#      20 self.host = host
#      21 self.port = port
# ---> 22 self.session = self._create_session()
#
# File ~\Python Unified\packages\bloomberg\src\bloomberg\api_helper\extractor_ref.py:34, in BloombergExtractor._create_session(self)
#      32     print("Sesión Bloomberg iniciada")
#      33 if not session.openService("//blp/refdata"):
# ---> 34     raise ConnectionError("No se pudo abrir el servicio //blp/refdata")
#      35 else:
# ...

# %%
df_ctry = be.ecfc_annual_table('Germany')
df_ctry
# Out:
# C:\Users\mpy\Python Unified\packages\bloomberg\src\bloomberg\api_helper\extractor_ref.py:326: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df[~df['description'].str.contains(r'\b(High|Low|Average)\b', case=False, na=False)]
# ECUPDE 26 Index
# ECUPDE 27 Index
# ECUPDE 28 Index
# ECUPDE 29 Index
# ECUPDE 30 Index
# ECUPDE 31 Index
# ECGDDE 26 Index
# ECGDDE 27 Index
# ECGDDE 28 Index
# ECGDDE 29 Index
# ECGDDE 30 Index
# ECGDDE 31 Index
# ECBBDE 26 Index
# ECBBDE 27 Index
# ECBBDE 28 Index
# ECBBDE 29 Index
# ECBBDE 30 Index
# ECBBDE 31 Index
# ECCADE 26 Index
# ECCADE 27 Index
# ECCADE 28 Index
# ECCADE 29 Index
# ECCADE 30 Index
# ECCADE 31 Index
# ECPIDE 26 Index
# ECPIDE 27 Index
# ECPIDE 28 Index
# ECPIDE 29 Index
# ECPIDE 30 Index
# ECPIDE 31 Index
# ECPIDE 26 Index
# ECPIDE 27 Index
# ECPIDE 28 Index
# ECPIDE 29 Index
# ECPIDE 30 Index
# ECPIDE 31 Index
# ECGVDE 26 Index
# ...

# %%
pool_securities = {
    'UK':'N2EXH',
    'ES':'OMLPHR',
    'IT':'GMEPIT',
    'PL':'PXPEDA',
    'IR':'SEMODE',
    'GE':'LPXBHR',
    'FR':'PWNXFR'
}

df_dam = be.extraction_prices(
    countries=pool_securities,
    startdate='20240101',
    enddate='20251230',
    # freq='D'
)
# Out:
# C:\Users\mpy\Python\bloomberg\src\bloomberg\api_helper\extractor_ref.py:159: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   out = df.groupby('Date', group_keys=False).apply(lambda g: transform(g[['Hour','Price']], g.name))
# C:\Users\mpy\Python\bloomberg\src\bloomberg\api_helper\extractor_ref.py:159: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...
